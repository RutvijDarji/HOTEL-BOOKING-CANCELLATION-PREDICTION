# %%
import pandas as pd

# %%
H1=pd.read_csv("H1.csv")
H1.head(2)
# Out:
#    IsCanceled  LeadTime  ArrivalDateYear ArrivalDateMonth  \
# 0           0       342             2015             July
# 1           0       737             2015             July
#
#    ArrivalDateWeekNumber  ArrivalDateDayOfMonth  StaysInWeekendNights  \
# 0                     27                      1                     0
# 1                     27                      1                     0
#
#    StaysInWeekNights  Adults  Children  ...      DepositType        Agent  \
# 0                  0       2         0  ...  No Deposit              NULL
# 1                  0       2         0  ...  No Deposit              NULL
#
#        Company DaysInWaitingList CustomerType  ADR  RequiredCarParkingSpaces  \
# 0         NULL                 0    Transient  0.0                         0
# 1         NULL                 0    Transient  0.0                         0
#
#    TotalOfSpecialRequests ReservationStatus ReservationStatusDate
# ...

# %%
H2=pd.read_csv("H2.csv")
H2.head(2)
# Out:
#    IsCanceled  LeadTime  ArrivalDateYear ArrivalDateMonth  \
# 0           0         6             2015             July
# 1           1        88             2015             July
#
#    ArrivalDateWeekNumber  ArrivalDateDayOfMonth  StaysInWeekendNights  \
# 0                     27                      1                     0
# 1                     27                      1                     0
#
#    StaysInWeekNights  Adults  Children  ...      DepositType        Agent  \
# 0                  2       1       0.0  ...  No Deposit                 6
# 1                  4       2       0.0  ...  No Deposit                 9
#
#        Company DaysInWaitingList CustomerType   ADR  RequiredCarParkingSpaces  \
# 0         NULL                 0    Transient   0.0                         0
# 1         NULL                 0    Transient  76.5                         0
#
#    TotalOfSpecialRequests ReservationStatus ReservationStatusDate
# ...

# %%
H1.dtypes
# Out:
# IsCanceled                       int64
# LeadTime                         int64
# ArrivalDateYear                  int64
# ArrivalDateMonth                object
# ArrivalDateWeekNumber            int64
# ArrivalDateDayOfMonth            int64
# StaysInWeekendNights             int64
# StaysInWeekNights                int64
# Adults                           int64
# Children                         int64
# Babies                           int64
# Meal                            object
# Country                         object
# MarketSegment                   object
# DistributionChannel             object
# IsRepeatedGuest                  int64
# PreviousCancellations            int64
# PreviousBookingsNotCanceled      int64
# ReservedRoomType                object
# AssignedRoomType                object
# BookingChanges                   int64
# DepositType                     object
# Agent                           object
# Company                         object
# ...

# %%
H2.dtypes
# Out:
# IsCanceled                       int64
# LeadTime                         int64
# ArrivalDateYear                  int64
# ArrivalDateMonth                object
# ArrivalDateWeekNumber            int64
# ArrivalDateDayOfMonth            int64
# StaysInWeekendNights             int64
# StaysInWeekNights                int64
# Adults                           int64
# Children                       float64
# Babies                           int64
# Meal                            object
# Country                         object
# MarketSegment                   object
# DistributionChannel             object
# IsRepeatedGuest                  int64
# PreviousCancellations            int64
# PreviousBookingsNotCanceled      int64
# ReservedRoomType                object
# AssignedRoomType                object
# BookingChanges                   int64
# DepositType                     object
# Agent                           object
# Company                         object
# ...

# %%
H1.shape
# Out:
# (40060, 31)

# %%
H1['Hotel']='resort hotel'
H1.head(2)
# Out:
#    IsCanceled  LeadTime  ArrivalDateYear ArrivalDateMonth  \
# 0           0       342             2015             July
# 1           0       737             2015             July
#
#    ArrivalDateWeekNumber  ArrivalDateDayOfMonth  StaysInWeekendNights  \
# 0                     27                      1                     0
# 1                     27                      1                     0
#
#    StaysInWeekNights  Adults  Children  ...        Agent      Company  \
# 0                  0       2         0  ...         NULL         NULL
# 1                  0       2         0  ...         NULL         NULL
#
#   DaysInWaitingList CustomerType  ADR  RequiredCarParkingSpaces  \
# 0                 0    Transient  0.0                         0
# 1                 0    Transient  0.0                         0
#
#    TotalOfSpecialRequests  ReservationStatus ReservationStatusDate  \
# 0                       0          Check-Out            2015-07-01
# ...

# %%
H2['Hotel']='city hotel'
H2.head(2)
# Out:
#    IsCanceled  LeadTime  ArrivalDateYear ArrivalDateMonth  \
# 0           0         6             2015             July
# 1           1        88             2015             July
#
#    ArrivalDateWeekNumber  ArrivalDateDayOfMonth  StaysInWeekendNights  \
# 0                     27                      1                     0
# 1                     27                      1                     0
#
#    StaysInWeekNights  Adults  Children  ...        Agent      Company  \
# 0                  2       1       0.0  ...            6         NULL
# 1                  4       2       0.0  ...            9         NULL
#
#   DaysInWaitingList CustomerType   ADR  RequiredCarParkingSpaces  \
# 0                 0    Transient   0.0                         0
# 1                 0    Transient  76.5                         0
#
#    TotalOfSpecialRequests  ReservationStatus ReservationStatusDate       Hotel
# 0                       0          Check-Out            2015-07-03  city hotel
# ...

# %%
H2.shape
# Out:
# (79330, 32)

# %%
HotelData=pd.concat([H1,H2],ignore_index=True)
HotelData.head(2)
# Out:
#    IsCanceled  LeadTime  ArrivalDateYear ArrivalDateMonth  \
# 0           0       342             2015             July
# 1           0       737             2015             July
#
#    ArrivalDateWeekNumber  ArrivalDateDayOfMonth  StaysInWeekendNights  \
# 0                     27                      1                     0
# 1                     27                      1                     0
#
#    StaysInWeekNights  Adults  Children  ...        Agent      Company  \
# 0                  0       2       0.0  ...         NULL         NULL
# 1                  0       2       0.0  ...         NULL         NULL
#
#   DaysInWaitingList CustomerType  ADR  RequiredCarParkingSpaces  \
# 0                 0    Transient  0.0                         0
# 1                 0    Transient  0.0                         0
#
#    TotalOfSpecialRequests  ReservationStatus ReservationStatusDate  \
# 0                       0          Check-Out            2015-07-01
# ...

# %%
HotelData.tail(2)
# Out:
#         IsCanceled  LeadTime  ArrivalDateYear ArrivalDateMonth  \
# 119388           0       109             2017           August
# 119389           0       205             2017           August
#
#         ArrivalDateWeekNumber  ArrivalDateDayOfMonth  StaysInWeekendNights  \
# 119388                     35                     31                     2
# 119389                     35                     29                     2
#
#         StaysInWeekNights  Adults  Children  ...        Agent      Company  \
# 119388                  5       2       0.0  ...           89         NULL
# 119389                  7       2       0.0  ...            9         NULL
#
#        DaysInWaitingList CustomerType    ADR  RequiredCarParkingSpaces  \
# 119388                 0    Transient  104.4                         0
# 119389                 0    Transient  151.2                         0
#
#         TotalOfSpecialRequests  ReservationStatus ReservationStatusDate  \
# ...

# %%
HotelData.shape
# Out:
# (119390, 32)

# %%
HotelData.dtypes
# Out:
# IsCanceled                       int64
# LeadTime                         int64
# ArrivalDateYear                  int64
# ArrivalDateMonth                object
# ArrivalDateWeekNumber            int64
# ArrivalDateDayOfMonth            int64
# StaysInWeekendNights             int64
# StaysInWeekNights                int64
# Adults                           int64
# Children                       float64
# Babies                           int64
# Meal                            object
# Country                         object
# MarketSegment                   object
# DistributionChannel             object
# IsRepeatedGuest                  int64
# PreviousCancellations            int64
# PreviousBookingsNotCanceled      int64
# ReservedRoomType                object
# AssignedRoomType                object
# BookingChanges                   int64
# DepositType                     object
# Agent                           object
# Company                         object
# ...

# %%
HotelData.isnull().sum()
# Out:
# IsCanceled                       0
# LeadTime                         0
# ArrivalDateYear                  0
# ArrivalDateMonth                 0
# ArrivalDateWeekNumber            0
# ArrivalDateDayOfMonth            0
# StaysInWeekendNights             0
# StaysInWeekNights                0
# Adults                           0
# Children                         4
# Babies                           0
# Meal                             0
# Country                        488
# MarketSegment                    0
# DistributionChannel              0
# IsRepeatedGuest                  0
# PreviousCancellations            0
# PreviousBookingsNotCanceled      0
# ReservedRoomType                 0
# AssignedRoomType                 0
# BookingChanges                   0
# DepositType                      0
# Agent                            0
# Company                          0
# DaysInWaitingList                0
# CustomerType                     0
# ADR                              0
# ...

# %%
HotelData['Country'].unique()
# Out:
# array(['PRT', 'GBR', 'USA', 'ESP', 'IRL', 'FRA', nan, 'ROU', 'NOR', 'OMN',
#        'ARG', 'POL', 'DEU', 'BEL', 'CHE', 'CN', 'GRC', 'ITA', 'NLD',
#        'DNK', 'RUS', 'SWE', 'AUS', 'EST', 'CZE', 'BRA', 'FIN', 'MOZ',
#        'BWA', 'LUX', 'SVN', 'ALB', 'IND', 'CHN', 'MEX', 'MAR', 'UKR',
#        'SMR', 'LVA', 'PRI', 'SRB', 'CHL', 'AUT', 'BLR', 'LTU', 'TUR',
#        'ZAF', 'AGO', 'ISR', 'CYM', 'ZMB', 'CPV', 'ZWE', 'DZA', 'KOR',
#        'CRI', 'HUN', 'ARE', 'TUN', 'JAM', 'HRV', 'HKG', 'IRN', 'GEO',
#        'AND', 'GIB', 'URY', 'JEY', 'CAF', 'CYP', 'COL', 'GGY', 'KWT',
#        'NGA', 'MDV', 'VEN', 'SVK', 'FJI', 'KAZ', 'PAK', 'IDN', 'LBN',
#        'PHL', 'SEN', 'SYC', 'AZE', 'BHR', 'NZL', 'THA', 'DOM', 'MKD',
#        'MYS', 'ARM', 'JPN', 'LKA', 'CUB', 'CMR', 'BIH', 'MUS', 'COM',
#        'SUR', 'UGA', 'BGR', 'CIV', 'JOR', 'SYR', 'SGP', 'BDI', 'SAU',
#        'VNM', 'PLW', 'QAT', 'EGY', 'PER', 'MLT', 'MWI', 'ECU', 'MDG',
# ...

# %%
HotelData=HotelData.dropna()

# %%
HotelData.isnull().sum().sum()
# Out:
# 0

# %%
HotelData.duplicated().sum()
# Out:
# 31958

# %%
HotelData=HotelData.drop_duplicates()

# %%
HotelData.duplicated().sum()
# Out:
# 0

# %%
HotelData.shape
# Out:
# (86940, 32)

# %%
HotelData.to_csv("HotelData.csv")

# %%
HotelData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 86940 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   IsCanceled                   86940 non-null  int64
#  1   LeadTime                     86940 non-null  int64
#  2   ArrivalDateYear              86940 non-null  int64
#  3   ArrivalDateMonth             86940 non-null  object
#  4   ArrivalDateWeekNumber        86940 non-null  int64
#  5   ArrivalDateDayOfMonth        86940 non-null  int64
#  6   StaysInWeekendNights         86940 non-null  int64
#  7   StaysInWeekNights            86940 non-null  int64
#  8   Adults                       86940 non-null  int64
#  9   Children                     86940 non-null  float64
#  10  Babies                       86940 non-null  int64
#  11  Meal                         86940 non-null  object
#  12  Country                      86940 non-null  object
# ...

# %%
co_matrix=round(HotelData.corr(),2) #Making correlation matrix to show the relationship between variables.
# Out:
# <ipython-input-20-1c95766698c6>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   co_matrix=round(HotelData.corr(),2) #Making correlation matrix to show the relationship between variables.

# %%
import matplotlib.pyplot as plt
import seaborn as sb

# %%
plt.figure(figsize = (24, 12))
sb.heatmap(co_matrix, annot=True, cmap="coolwarm") # Making heatmap to visualise correlation matrix in better way. Here Annot:: used to print value , coolwarm::need to show color range
plt.show()

# %%
useless_col=["ArrivalDateWeekNumber","ArrivalDateDayOfMonth","Babies","DaysInWaitingList"]

# %%
HotelData = HotelData.drop(useless_col,axis=1)

# %%
HotelData['DistributionChannel'].unique()
# Out:
# array(['Direct', 'Corporate', 'TA/TO', 'Undefined', 'GDS'], dtype=object)

# %%
HotelData['MarketSegment'].unique()
# Out:
# array(['Direct', 'Corporate', 'Online TA', 'Offline TA/TO',
#        'Complementary', 'Groups', 'Aviation'], dtype=object)

# %%
from scipy import stats

# %%
from scipy.stats import chi2_contingency

# %%
contingency_table = pd.crosstab(HotelData['DistributionChannel'],HotelData['MarketSegment'])

# %%
chi2, p, dof, expected = chi2_contingency(contingency_table)

# %%
if p < 0.05:
    print("There is a significant association between DistributionChannel and MarketSegment.")
else:
    print("There is no significant association between DistributionChannel and MarketSegment.")
# Out:
# There is a significant association between DistributionChannel and MarketSegment.

# %%
HotelData=HotelData.drop("DistributionChannel",axis=1)

# %%
contingency_table_2 = pd.crosstab(HotelData['ReservedRoomType'],HotelData['AssignedRoomType'])

# %%
chi2_2, p_2, dof_2, expected_2 = chi2_contingency(contingency_table_2)

# %%
if p_2 < 0.05:
    print("There is a significant association between ReservedRoomType and AssignedRoomType.")
else:
    print("There is no significant association between ReservedRoomType and AssignedRoomType.")
# Out:
# There is a significant association between ReservedRoomType and AssignedRoomType.

# %%
HotelData=HotelData.drop("ReservedRoomType",axis=1)

# %%
HotelData=HotelData.drop(["ReservationStatusDate","ADR"],axis=1)

# %%
HotelData['Agent'].value_counts()
# Out:
#           9    28757
#         240    12977
#        NULL    11866
#          14     3347
#           7     3300
#                ...
#         257        1
#         291        1
#          93        1
#         483        1
#         449        1
# Name: Agent, Length: 333, dtype: int64

# %%
HotelData['Agent'].shape
# Out:
# (86940,)

# %%
HotelData['Company'].value_counts()
# Out:
#        NULL    81848
#          40      851
#         223      503
#          45      238
#         153      206
#                ...
#          76        1
#          32        1
#         487        1
#         516        1
#         402        1
# Name: Company, Length: 350, dtype: int64

# %%
HotelData=HotelData.drop("Company",axis=1)

# %%
HotelData=HotelData.drop("Agent",axis=1)

# %%
#HotelData['IsCanceled']=HotelData['IsCanceled'].astype("category")
HotelData['ArrivalDateMonth']=HotelData['ArrivalDateMonth'].astype("category")
HotelData['Meal']=HotelData['Meal'].astype("category")
HotelData['Country']=HotelData['Country'].astype("category")
HotelData['MarketSegment']=HotelData['MarketSegment'].astype("category")
#HotelData['DistributionChannel']=HotelData['DistributionChannel'].astype("category")
HotelData['IsRepeatedGuest']=HotelData['IsRepeatedGuest'].astype("category")
#HotelData['ReservedRoomType']=HotelData['ReservedRoomType'].astype("category")
HotelData['AssignedRoomType']=HotelData['AssignedRoomType'].astype("category")
HotelData['DepositType']=HotelData['DepositType'].astype("category")
#HotelData['Agent']=HotelData['Agent'].astype("category")
#HotelData['Company']=HotelData['Company'].astype("category")
HotelData['CustomerType']=HotelData['CustomerType'].astype("category")
HotelData['ReservationStatus']=HotelData['ReservationStatus'].astype("category")
#HotelData['ReservationStatusDate']=pd.to_datetime(HotelData['ReservationStatusDate'])
HotelData['Hotel']=HotelData['Hotel'].astype("category")

# %%
HotelData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 86940 entries, 0 to 119389
# Data columns (total 23 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   IsCanceled                   86940 non-null  int64
#  1   LeadTime                     86940 non-null  int64
#  2   ArrivalDateYear              86940 non-null  int64
#  3   ArrivalDateMonth             86940 non-null  object
#  4   StaysInWeekendNights         86940 non-null  int64
#  5   StaysInWeekNights            86940 non-null  int64
#  6   Adults                       86940 non-null  int64
#  7   Children                     86940 non-null  float64
#  8   Meal                         86940 non-null  object
#  9   Country                      86940 non-null  object
#  10  MarketSegment                86940 non-null  object
#  11  IsRepeatedGuest              86940 non-null  int64
#  12  PreviousCancellations        86940 non-null  int64
# ...

# %%
HotelData.to_csv("HotelData_new.csv")

# %%
HotelData.shape
# Out:
# (86940, 25)

# %%
HotelData['IsCanceled'].value_counts()
# Out:
# 0    62953
# 1    23987
# Name: IsCanceled, dtype: int64

# %%
HotelData.describe().T
# Out:
#                                count         mean        std     min     25%  \
# IsCanceled                   86940.0     0.275903   0.446971     0.0     0.0
# LeadTime                     86940.0    80.193375  86.100147     0.0    12.0
# ArrivalDateYear              86940.0  2016.211824   0.686016  2015.0  2016.0
# StaysInWeekendNights         86940.0     1.007396   1.028763     0.0     0.0
# StaysInWeekNights            86940.0     2.628744   2.043753     0.0     1.0
# Adults                       86940.0     1.878525   0.625860     0.0     2.0
# Children                     86940.0     0.139211   0.456786     0.0     0.0
# PreviousCancellations        86940.0     0.030228   0.369574     0.0     0.0
# PreviousBookingsNotCanceled  86940.0     0.176708   1.717885     0.0     0.0
# BookingChanges               86940.0     0.271854   0.728090     0.0     0.0
# RequiredCarParkingSpaces     86940.0     0.083448   0.280402     0.0     0.0
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sb

#import warnings

#warnings.filterwarnings("ignore")

fig, axes = plt.subplots(1,2, figsize=(10,3)) #plt.subplots()::creates a figure and one row with two columns of subplots (1 row and 2 columns).

sb.histplot(HotelData['LeadTime'],bins=10,ax=axes[0]) #bin::number of bins (intervals) in the histogram.

plt.boxplot(HotelData['LeadTime'],patch_artist = True) #patch_artist::used to fill the boxes with colors in the box plot.

axes[0].set_title('Distribution of the LeadTime')

axes[1].set_title('Range of the price of the LeadTime')

plt.tight_layout()

plt.show()

# %%
import numpy as np


HotelData['LeadTime'] = np.log(HotelData['LeadTime'])
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py:402: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
import matplotlib.pyplot as plt
import seaborn as sb

#import warnings

#warnings.filterwarnings("ignore")

fig, axes = plt.subplots(1,2, figsize=(10,3)) #plt.subplots()::creates a figure and one row with two columns of subplots (1 row and 2 columns).

sb.histplot(HotelData['LeadTime'],bins=10,ax=axes[0]) #bin::number of bins (intervals) in the histogram.

plt.boxplot(HotelData['LeadTime'],patch_artist = True) #patch_artist::used to fill the boxes with colors in the box plot.

axes[0].set_title('Distribution of the LeadTime')

axes[1].set_title('Range of the price of the LeadTime')

plt.tight_layout()

plt.show()

# %%
fig, axes = plt.subplots(1,2, figsize=(10,3)) #plt.subplots()::creates a figure and one row with two columns of subplots (1 row and 2 columns).
sb.histplot(HotelData['ArrivalDateYear'],bins=10,ax=axes[0]) #bin::number of bins (intervals) in the histogram.

plt.boxplot(HotelData['ArrivalDateYear'],patch_artist = True)#patch_artist::used to fill the boxes with colors in the box plot.

axes[0].set_title('Distribution of the ArrivalDateYear')

axes[1].set_title('Range of the ArrivalDateYear')

plt.tight_layout()

plt.show()

# %%
fig, axes = plt.subplots(1,2, figsize=(10,3)) #plt.subplots()::creates a figure and one row with two columns of subplots (1 row and 2 columns).
sb.histplot(HotelData['StaysInWeekendNights'],bins=10,ax=axes[0]) #bin::number of bins (intervals) in the histogram.
plt.boxplot(HotelData['StaysInWeekendNights'],patch_artist = True)#patch_artist::used to fill the boxes with colors in the box plot.
axes[0].set_title('Distribution of the StaysInWeekendNights')

axes[1].set_title('Range of the StaysInWeekendNights')

plt.tight_layout()

plt.show()

# %%
Q1=HotelData['StaysInWeekendNights'].quantile(0.25)
Q3=HotelData['StaysInWeekendNights'].quantile(0.75)
IQR= Q3 - Q1
Upperbound_StaysInWeekendNights = Q3 + 1.5*IQR
Index2=HotelData.loc[HotelData['StaysInWeekendNights']>Upperbound_StaysInWeekendNights,"StaysInWeekendNights"].index
HotelData=HotelData.drop(Index2)
fig, axes = plt.subplots(1,2, figsize=(10,3))

sb.histplot(HotelData['StaysInWeekendNights'],bins=10,ax=axes[0])

plt.boxplot(HotelData['StaysInWeekendNights'],patch_artist = True)

axes[0].set_title('Distribution of the StaysInWeekendNights')

axes[1].set_title('Range of the StaysInWeekendNights')

plt.tight_layout()

plt.show()

# %%
fig, axes = plt.subplots(1,2, figsize=(10,3)) #plt.subplots()::creates a figure and one row with two columns of subplots (1 row and 2 columns).
sb.histplot(HotelData['StaysInWeekNights'],bins=10,ax=axes[0])#bin::number of bins (intervals) in the histogram.
plt.boxplot(HotelData['StaysInWeekNights'],patch_artist = True) #patch_artist::used to fill the boxes with colors in the box plot.
axes[0].set_title('Distribution of the StaysInWeekNights')

axes[1].set_title('Range of the StaysInWeekNights')

plt.tight_layout()

plt.show()

# %%
Q1=HotelData['StaysInWeekNights'].quantile(0.25)
Q3=HotelData['StaysInWeekNights'].quantile(0.75)
IQR= Q3 - Q1
Upperbound_StaysInWeekNights = Q3 + 1.5*IQR
Index2=HotelData.loc[HotelData['StaysInWeekNights']>Upperbound_StaysInWeekNights,"StaysInWeekNights"].index
HotelData=HotelData.drop(Index2)
fig, axes = plt.subplots(1,2, figsize=(10,3))

sb.histplot(HotelData['StaysInWeekNights'],bins=10,ax=axes[0])

plt.boxplot(HotelData['StaysInWeekNights'],patch_artist = True)

axes[0].set_title('Distribution of the StaysInWeekNights')

axes[1].set_title('Range of the StaysInWeekNights')

plt.tight_layout()

plt.show()

# %%
fig, axes = plt.subplots(1,2, figsize=(10,3)) #plt.subplots()::creates a figure and one row with two columns of subplots (1 row and 2 columns).
sb.histplot(HotelData['Adults'],bins=10,ax=axes[0]) #bin::number of bins (intervals) in the histogram.
plt.boxplot(HotelData['Adults'],patch_artist = True) #patch_artist::used to fill the boxes with colors in the box plot.
axes[0].set_title('Distribution of the Adults')

axes[1].set_title('Range of the Adults')

plt.tight_layout()

plt.show()

# %%
HotelData['Adults_Ranked']=pd.DataFrame(np.argsort(np.sort(HotelData['Adults'])).argsort() + 1)

# %%
HotelData['Adults'].value_counts()
# Out:
# 2     64340
# 1     16214
# 3      5930
# 0       380
# 4        60
# 26        5
# 27        2
# 20        2
# 5         2
# 40        1
# 50        1
# 55        1
# 6         1
# 10        1
# Name: Adults, dtype: int64

# %%
HotelData['Adults_Ranked'].unique()
# Out:
# array([1.0000e+00, 2.5800e+02, 2.5700e+02, ..., 8.6939e+04, 8.6940e+04,
#               nan])

# %%
fig, axes = plt.subplots(1,2, figsize=(10,3)) #plt.subplots()::creates a figure and one row with two columns of subplots (1 row and 2 columns).
sb.histplot(HotelData['Adults_Ranked'],bins=10,ax=axes[0]) #bin::number of bins (intervals) in the histogram.
plt.boxplot(HotelData['Adults_Ranked'],patch_artist = True) #patch_artist::used to fill the boxes with colors in the box plot.
axes[0].set_title('Distribution of the Adults')

axes[1].set_title('Range of the Adults')

plt.tight_layout()

plt.show()

# %%
HotelData['Adults'].unique()
# Out:
# array([ 2,  1,  3,  4, 40, 26, 50, 27, 55,  0, 20,  6,  5, 10])

# %%
lower_percentile = np.percentile(HotelData['Adults'], 1)
upper_percentile = np.percentile(HotelData['Adults'], 99)

# %%
HotelData['Adults'] = np.where(HotelData['Adults']< lower_percentile, lower_percentile, HotelData['Adults'])
HotelData['Adults'] = np.where(HotelData['Adults'] > upper_percentile, upper_percentile, HotelData['Adults'])

# %%
fig, axes = plt.subplots(1,2, figsize=(10,3)) #plt.subplots()::creates a figure and one row with two columns of subplots (1 row and 2 columns).
sb.histplot(HotelData['Adults'],bins=10,ax=axes[0]) #bin::number of bins (intervals) in the histogram.
plt.boxplot(HotelData['Adults'],patch_artist = True) #patch_artist::used to fill the boxes with colors in the box plot.
axes[0].set_title('Distribution of the Adults')

axes[1].set_title('Range of the Adults')

plt.tight_layout()

plt.show()

# %%
HotelData['Adults']=np.log(HotelData['Adults'])
fig, axes = plt.subplots(1,2, figsize=(10,3)) #plt.subplots()::creates a figure and one row with two columns of subplots (1 row and 2 columns).
sb.histplot(HotelData['Adults'],bins=10,ax=axes[0]) #bin::number of bins (intervals) in the histogram.
plt.boxplot(HotelData['Adults'],patch_artist = True) #patch_artist::used to fill the boxes with colors in the box plot.
axes[0].set_title('Distribution of the Adults')

axes[1].set_title('Range of the Adults')

plt.tight_layout()

plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py:402: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
fig, axes = plt.subplots(1,2, figsize=(10,3)) #plt.subplots()::creates a figure and one row with two columns of subplots (1 row and 2 columns).
sb.histplot(HotelData['Children'],bins=10,ax=axes[0]) #bin::number of bins (intervals) in the histogram.
plt.boxplot(HotelData['Children'],patch_artist = True) #patch_artist::used to fill the boxes with colors in the box plot.
axes[0].set_title('Distribution of the Children')

axes[1].set_title('Range of the Children')

plt.tight_layout()

plt.show()

# %%
fig, axes = plt.subplots(1,2, figsize=(10,3)) #plt.subplots()::creates a figure and one row with two columns of subplots (1 row and 2 columns).
sb.histplot(HotelData['PreviousCancellations'],bins=10,ax=axes[0]) #bin::number of bins (intervals) in the histogram.
plt.boxplot(HotelData['PreviousCancellations'],patch_artist = True) #patch_artist::used to fill the boxes with colors in the box plot.
axes[0].set_title('Distribution of the PreviousCancellations')

axes[1].set_title('Range of the PreviousCancellations')

plt.tight_layout()

plt.show()

# %%
HotelData['PreviousCancellations']=np.log(HotelData['PreviousCancellations'])
fig, axes = plt.subplots(1,2, figsize=(10,3)) #plt.subplots()::creates a figure and one row with two columns of subplots (1 row and 2 columns).
sb.histplot(HotelData['PreviousCancellations'],bins=10,ax=axes[0]) #bin::number of bins (intervals) in the histogram.
plt.boxplot(HotelData['PreviousCancellations'],patch_artist = True) #patch_artist::used to fill the boxes with colors in the box plot.
axes[0].set_title('Distribution of the PreviousCancellations')

axes[1].set_title('Range of the PreviousCancellations')

plt.tight_layout()

plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py:402: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:4527: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)

# %%
fig, axes = plt.subplots(1,2, figsize=(10,3)) #plt.subplots()::creates a figure and one row with two columns of subplots (1 row and 2 columns).
sb.histplot(HotelData['PreviousBookingsNotCanceled'],bins=10,ax=axes[0]) #bin::number of bins (intervals) in the histogram.
plt.boxplot(HotelData['PreviousBookingsNotCanceled'],patch_artist = True) #patch_artist::used to fill the boxes with colors in the box plot.
axes[0].set_title('Distribution of the PreviousBookingsNotCanceled')

axes[1].set_title('Range of the PreviousBookingsNotCanceled')

plt.tight_layout()

plt.show()

# %%
HotelData['PreviousBookingsNotCanceled']= np.log(HotelData['PreviousBookingsNotCanceled'])
fig, axes = plt.subplots(1,2, figsize=(10,3)) #plt.subplots()::creates a figure and one row with two columns of subplots (1 row and 2 columns).
sb.histplot(HotelData['PreviousBookingsNotCanceled'],bins=10,ax=axes[0]) #bin::number of bins (intervals) in the histogram.
plt.boxplot(HotelData['PreviousBookingsNotCanceled'],patch_artist = True) #patch_artist::used to fill the boxes with colors in the box plot.
axes[0].set_title('Distribution of the PreviousBookingsNotCanceled')

axes[1].set_title('Range of the PreviousBookingsNotCanceled')

plt.tight_layout()

plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py:402: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:4527: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)

# %%
fig, axes = plt.subplots(1,2, figsize=(10,3)) #plt.subplots()::creates a figure and one row with two columns of subplots (1 row and 2 columns).
sb.histplot(HotelData['BookingChanges'],bins=10,ax=axes[0]) #bin::number of bins (intervals) in the histogram.
plt.boxplot(HotelData['BookingChanges'],patch_artist = True) #patch_artist::used to fill the boxes with colors in the box plot.
axes[0].set_title('Distribution of the BookingChanges')

axes[1].set_title('Range of the BookingChanges')

plt.tight_layout()

plt.show()

# %%
fig, axes = plt.subplots(1,2, figsize=(10,3)) #plt.subplots()::creates a figure and one row with two columns of subplots (1 row and 2 columns).
sb.histplot(HotelData['RequiredCarParkingSpaces'],bins=10,ax=axes[0]) #bin::number of bins (intervals) in the histogram.
plt.boxplot(HotelData['RequiredCarParkingSpaces'],patch_artist = True) #patch_artist::used to fill the boxes with colors in the box plot.
axes[0].set_title('Distribution of the RequiredCarParkingSpaces')

axes[1].set_title('Range of the RequiredCarParkingSpaces')

plt.tight_layout()

plt.show()

# %%
fig, axes = plt.subplots(1,2, figsize=(10,3)) #plt.subplots()::creates a figure and one row with two columns of subplots (1 row and 2 columns).
sb.histplot(HotelData['TotalOfSpecialRequests'],bins=10,ax=axes[0]) #bin::number of bins (intervals) in the histogram.
plt.boxplot(HotelData['TotalOfSpecialRequests'],patch_artist = True) #patch_artist::used to fill the boxes with colors in the box plot.
axes[0].set_title('Distribution of the TotalOfSpecialRequests')

axes[1].set_title('Range of the TotalOfSpecialRequests')

plt.tight_layout()

plt.show()

# %%
Q1=HotelData['TotalOfSpecialRequests'].quantile(0.25)

Q3=HotelData['TotalOfSpecialRequests'].quantile(0.75)
IQR= Q3 - Q1
Upperbound_leadtime = Q3 + 1.5*IQR
Index1=HotelData.loc[HotelData['TotalOfSpecialRequests']>Upperbound_leadtime,"TotalOfSpecialRequests"].index
#Index1:: showing the index of outliers #loc::method using for data manipulation and analysis.
HotelData=HotelData.drop(Index1)
fig, axes = plt.subplots(1,2, figsize=(10,3))

sb.histplot(HotelData['TotalOfSpecialRequests'],bins=10,ax=axes[0])

plt.boxplot(HotelData['TotalOfSpecialRequests'],patch_artist = True)

axes[0].set_title('Distribution of the TotalOfSpecialRequests')

axes[1].set_title('Range of the TotalOfSpecialRequests')

plt.tight_layout()

plt.show()

# %%
HotelData.dtypes
# Out:
# IsCanceled                        int64
# LeadTime                        float64
# ArrivalDateYear                   int64
# ArrivalDateMonth               category
# StaysInWeekendNights              int64
# StaysInWeekNights                 int64
# Adults                            int64
# Children                        float64
# Meal                           category
# Country                        category
# MarketSegment                  category
# IsRepeatedGuest                category
# PreviousCancellations             int64
# PreviousBookingsNotCanceled       int64
# ReservedRoomType               category
# AssignedRoomType               category
# BookingChanges                    int64
# DepositType                    category
# Agent                          category
# Company                        category
# CustomerType                   category
# RequiredCarParkingSpaces          int64
# TotalOfSpecialRequests            int64
# ...

# %%
HotelData['ArrivalDateMonth'].unique()
# Out:
# ['July', 'August', 'September', 'October', 'November', ..., 'February', 'March', 'April', 'May', 'June']
# Length: 12
# Categories (12, object): ['April', 'August', 'December', 'February', ..., 'May', 'November',
#                           'October', 'September']

# %%
my1 = HotelData.loc[HotelData['ArrivalDateMonth'] == 'January', ].shape[0] # .loc method is used to filter the DataFrame based on the condition

my2 = HotelData.loc[HotelData['ArrivalDateMonth'] == 'February', ].shape[0] #shape[0] is used to get the number of rows that meet the condition.

my3 = HotelData.loc[HotelData['ArrivalDateMonth'] == 'March', ].shape[0]

my4 = HotelData.loc[HotelData['ArrivalDateMonth'] == 'April', ].shape[0]

my5 = HotelData.loc[HotelData['ArrivalDateMonth'] == 'May', ].shape[0]

my6 = HotelData.loc[HotelData['ArrivalDateMonth'] == 'June', ].shape[0]

my7 = HotelData.loc[HotelData['ArrivalDateMonth'] == 'July', ].shape[0]

my8 = HotelData.loc[HotelData['ArrivalDateMonth'] == 'August', ].shape[0]

my9 = HotelData.loc[HotelData['ArrivalDateMonth'] == 'September', ].shape[0]

my10 = HotelData.loc[HotelData['ArrivalDateMonth'] == 'October', ].shape[0]

my11 = HotelData.loc[HotelData['ArrivalDateMonth'] == 'November', ].shape[0]

my12= HotelData.loc[HotelData['ArrivalDateMonth'] == 'December', ].shape[0]

slice = [my1,my2,my3,my4,my5,my6,my7,my8,my9,my10,my11,my12]

labels = ["jan", "feb","mar.","apr","may","jun","jul","aug","sep","oct","nov","dec"]

plt.bar(labels, slice, color=['red', 'blue'], edgecolor='black')
plt.xlabel('ArivalMonth')

plt.ylabel('Count')

plt.title('Distribution of ArivalMonth')

plt.tight_layout()

plt.show()

# %%
HotelData['Meal'].unique()
# Out:
# ['BB       ', 'FB       ', 'HB       ', 'SC       ', 'Undefined']
# Categories (5, object): ['BB       ', 'FB       ', 'HB       ', 'SC       ', 'Undefined']

# %%
meal1 = HotelData.loc[HotelData['Meal'] == 'BB       ', ].shape[0] # .loc method is used to filter the DataFrame based on the condition

meal2 = HotelData.loc[HotelData['Meal'] == 'FB       ', ].shape[0] #shape[0] is used to get the number of rows that meet the condition.

meal3 = HotelData.loc[HotelData['Meal'] == 'HB       ', ].shape[0]

meal4 = HotelData.loc[HotelData['Meal'] == 'SC       ', ].shape[0]

meal5 = HotelData.loc[HotelData['Meal'] == 'Undefined', ].shape[0]

slice = [meal1,meal2,meal3,meal4,meal5]

labels = ["BB", "FB","HB","SC","Undefined"]

plt.bar(labels, slice, color=['red', 'blue'], edgecolor='black')
plt.xlabel('Meal')

plt.ylabel('Count')

plt.title('Distribution of Meal')

plt.tight_layout()

plt.show()

# %%
HotelData['ReservationStatus'].unique()
# Out:
# ['Check-Out', 'Canceled', 'No-Show']
# Categories (3, object): ['Canceled', 'Check-Out', 'No-Show']

# %%
rs1= HotelData.loc[HotelData['ReservationStatus'] == 'Canceled', ].shape[0]

rs2= HotelData.loc[HotelData['ReservationStatus'] == 'Check-Out', ].shape[0]

rs3= HotelData.loc[HotelData['ReservationStatus'] == 'No-Show', ].shape[0]

slice = [rs1,rs2,rs3]

labels = ["Canceled", "Check-Out","No-Show"]

explode = [0.1, 0.1,0.1] #explode list specifies how much each wedge of the pie should be separated from the center.



plt.pie(slice, labels=labels, explode=explode, autopct='%1.2f%%', shadow=True, wedgeprops={'edgecolor': 'black'}, startangle=360) #autopct='%1.2f%%' parameter displays the percentage of each slice on the pie.

plt.axis('equal') #plt.axis('equal'): This ensures that the pie chart is drawn as a circle (equal aspect ratio).

plt.title("Distribution of ReservationStatus")

plt.legend()

plt.tight_layout()

plt.show()

# %%
HotelData.dtypes
# Out:
# IsCanceled                        int64
# LeadTime                        float64
# ArrivalDateYear                   int64
# ArrivalDateMonth               category
# StaysInWeekendNights              int64
# StaysInWeekNights                 int64
# Adults                            int64
# Children                        float64
# Meal                           category
# Country                        category
# MarketSegment                  category
# IsRepeatedGuest                category
# PreviousCancellations             int64
# PreviousBookingsNotCanceled       int64
# ReservedRoomType               category
# AssignedRoomType               category
# BookingChanges                    int64
# DepositType                    category
# Agent                          category
# Company                        category
# CustomerType                   category
# RequiredCarParkingSpaces          int64
# TotalOfSpecialRequests            int64
# ...

# %%
HotelData['ArrivalDateMonth']=HotelData['ArrivalDateMonth'].cat.codes

# %%
HotelData['Meal']=HotelData['Meal'].cat.codes
HotelData['Country']=HotelData['Country'].cat.codes
HotelData['MarketSegment']=HotelData['MarketSegment'].cat.codes
HotelData['IsRepeatedGuest']=HotelData['IsRepeatedGuest'].cat.codes

# %%
HotelData['ReservedRoomType']=HotelData['ReservedRoomType'].cat.codes
HotelData['AssignedRoomType']=HotelData['AssignedRoomType'].cat.codes
HotelData['DepositType']=HotelData['DepositType'].cat.codes
HotelData['Agent']=HotelData['Agent'].cat.codes
HotelData['Company']=HotelData['Company'].cat.codes
HotelData['CustomerType']=HotelData['CustomerType'].cat.codes

# %%
HotelData['ReservationStatus']=HotelData['ReservationStatus'].cat.codes
HotelData['Hotel']=HotelData['Hotel'].cat.codes

# %%
HotelData.dtypes
# Out:
# IsCanceled                        int64
# LeadTime                        float64
# ArrivalDateYear                   int64
# ArrivalDateMonth               category
# StaysInWeekendNights              int64
# StaysInWeekNights                 int64
# Adults                            int64
# Children                        float64
# Meal                           category
# Country                        category
# MarketSegment                  category
# IsRepeatedGuest                category
# PreviousCancellations             int64
# PreviousBookingsNotCanceled       int64
# ReservedRoomType               category
# AssignedRoomType               category
# BookingChanges                    int64
# DepositType                    category
# Agent                          category
# Company                        category
# CustomerType                   category
# RequiredCarParkingSpaces          int64
# TotalOfSpecialRequests            int64
# ...

# %%
HotelData.to_csv("Hotel.csv")

# %%
HotelData_encode= pd.get_dummies(HotelData)

# %%
HotelData_encode.head(2)
# Out:
#    IsCanceled  LeadTime  ArrivalDateYear  StaysInWeekendNights  \
# 0           0  5.834811             2015                     0
# 1           0  6.602588             2015                     0
#
#    StaysInWeekNights  Adults  Children  PreviousCancellations  \
# 0                  0       2       0.0                      0
# 1                  0       2       0.0                      0
#
#    PreviousBookingsNotCanceled  BookingChanges  ...  \
# 0                            0               3  ...
# 1                            0               4  ...
#
#    DepositType_Refundable       CustomerType_Contract  CustomerType_Group  \
# 0                            0                      0                   0
# 1                            0                      0                   0
#
#    CustomerType_Transient  CustomerType_Transient-Party  \
# 0                       1                             0
# 1                       1                             0
#
# ...

# %%
HotelData_encode.shape
# Out:
# (82806, 239)

# %%
HotelData_dfx=HotelData_encode.drop("IsCanceled",axis=1) #Inputdataset

# %%
HotelData_dfy=HotelData_encode['IsCanceled'] #Target variables

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
scaled_HotelData_dfx=pd.DataFrame(scaler.fit_transform(HotelData_dfx),columns=HotelData_dfx.columns)

# %%
HotelData_dfx = HotelData_dfx.apply(lambda x: x.clip(lower=x.quantile(0.01), upper=x.quantile(0.99)))
HotelData_dfx= HotelData_dfx.apply(lambda x: x.apply(np.log1p))
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:4527: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)

# %%
scaled_HotelData_dfx.head(2)
# Out:
#    LeadTime  ArrivalDateYear  StaysInWeekendNights  StaysInWeekNights  \
# 0  1.031234        -1.765309             -1.126842          -2.240897
# 1  1.035130        -1.765309             -1.126842          -2.240897
#
#     Adults  Children  PreviousCancellations  PreviousBookingsNotCanceled  \
# 0  0.31953 -0.312308              -0.137659                    -0.185575
# 1  0.31953 -0.312308              -0.137659                    -0.185575
#
#    BookingChanges  RequiredCarParkingSpaces  ...  DepositType_Refundable       \
# 0        3.639781                 -0.300306  ...                          0.0
# 1        3.639781                 -0.300306  ...                          0.0
#
#    CustomerType_Contract  CustomerType_Group  CustomerType_Transient  \
# 0              -0.183133                 0.0                0.462028
# 1              -0.183133                 0.0                0.462028
#
#    CustomerType_Transient-Party  ReservationStatus_Canceled  \
# ...

# %%
scaled_HotelData_dfx.isnull().sum()
# Out:
# LeadTime                       5789
# ArrivalDateYear                   0
# StaysInWeekendNights              0
# StaysInWeekNights                 0
# Adults                            0
#                                ...
# ReservationStatus_Canceled        0
# ReservationStatus_Check-Out       0
# ReservationStatus_No-Show         0
# Hotel_city hotel                  0
# Hotel_resort hotel                0
# Length: 238, dtype: int64

# %%
mean=scaled_HotelData_dfx['LeadTime'].mean()

# %%
scaled_HotelData_dfx['LeadTime']=scaled_HotelData_dfx['LeadTime'].fillna(value=mean)

# %%
scaled_HotelData_dfx.isnull().sum().sum()
# Out:
# 0

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

pca = PCA()
pca.fit(scaled_HotelData_dfx)  # X is your data

plt.plot(range(1, len(pca.explained_variance_ratio_)+1), pca.explained_variance_ratio_)
#plt.plot(range(1,11), pca.explained_variance_ratio_[:10])
plt.xlabel("Number of Principal Components")
plt.ylabel("Explained Variance Ratio")
plt.show()

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

pca = PCA()
pca.fit(scaled_HotelData_dfx)  # X is your data

#plt.plot(range(1, len(pca.explained_variance_ratio_)+1), pca.explained_variance_ratio_)
plt.plot(range(1,31), pca.explained_variance_ratio_[:30])
plt.xlabel("Number of Principal Components")
plt.ylabel("Explained Variance Ratio")
plt.show()

# %%
from sklearn.decomposition import PCA

pca_dt = PCA(n_components=3)

principalComponents_4 = pca_dt.fit_transform(scaled_HotelData_dfx)

principalDf = pd.DataFrame(data = principalComponents_4)# columns = ['principal component 1', 'principal component 2','principal component 3','principal component 4'])

# %%
principalDf.head(2)
# Out:
#           0         1         2
# 0  1.975446 -2.310925 -1.465651
# 1  1.974766 -2.311380 -1.465242

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(principalDf,HotelData_dfy,test_size=0.2,random_state=3)

# %%
y_train.value_counts()
# Out:
# 0    47784
# 1    18460
# Name: IsCanceled, dtype: int64

# %%
from imblearn.over_sampling import SMOTE

# %%
S=SMOTE()

# %%
in_train_over,op_train_over=S.fit_resample(x_train,y_train)

# %%
op_train_over.value_counts()
# Out:
# 1    47784
# 0    47784
# Name: IsCanceled, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression

# %%
LG=LogisticRegression()

# %%
LG.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
pred_LG=LG.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
LG_acc=round(accuracy_score(pred_LG,y_test)*100,2)

# %%
LG_acc
# Out:
# 80.48

# %%
from sklearn.model_selection import cross_val_score

# %%
scores = cross_val_score(LG, principalDf, HotelData_dfy, cv=5)
# Print the accuracy for each fold and the mean accuracy
print("Cross-Validation Scores:",np.round(scores*100,2))
print("Mean Accuracy:", round(scores.mean()*100,2))
# Out:
# Cross-Validation Scores: [72.67 76.6  86.83 84.77 70.26]
# Mean Accuracy: 78.23

# %%
from sklearn.metrics import confusion_matrix

# %%
cf_matrix_LG= confusion_matrix(y_test,pred_LG)
cf_matrix_LG
# Out:
# array([[11122,   859],
#        [ 2374,  2207]])

# %%
ax = sb.heatmap(((cf_matrix_LG)/np.sum(cf_matrix_LG)), annot=True, cmap='Blues')

ax.set_title('Confusion Matrix corresponding to Logestic Regression model \n')

ax.set_xlabel('\nPredicted Values')

ax.set_ylabel('Actual Values ')

## Ticket labels - List must be in alphabetical order

ax.xaxis.set_ticklabels(['0','1'])

ax.yaxis.set_ticklabels(['0','1'])

plt.show()

# %%
from sklearn.metrics import classification_report

# %%
report=classification_report(y_test,pred_LG)

# %%
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.93      0.87     11981
#            1       0.72      0.48      0.58      4581
#
#     accuracy                           0.80     16562
#    macro avg       0.77      0.71      0.73     16562
# weighted avg       0.80      0.80      0.79     16562
